# %% [markdown]
# <a href="https://colab.research.google.com/github/sarrra48/ai/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow numpy matplotlib

# %%
import tensorflow as tf
import pathlib

DATASET_URL = "http://download.tensorflow.org/data/speech_commands_v0.01.tar.gz"


downloaded_file = tf.keras.utils.get_file(
    fname='speech_commands_v0.01.tar.gz',
    origin=DATASET_URL,
    extract=True
)

print("Downloaded file:", downloaded_file)
# Out:
# Downloaded file: /root/.keras/datasets/speech_commands_v0_extracted

# %%
import pathlib

data_dir = pathlib.Path("/root/.keras/datasets/speech_commands_v0_extracted")

# Make sure it exists
if data_dir.is_dir():
    print("Dataset folder found:", data_dir)
else:
    raise FileNotFoundError("Dataset folder not found!")

# List all classes except background noise
all_classes = [d.name for d in data_dir.iterdir() if d.is_dir() and d.name != "_background_noise_"]
all_classes.sort()
print("Classes:", all_classes)
# Out:
# Dataset folder found: /root/.keras/datasets/speech_commands_v0_extracted
# Classes: ['bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'four', 'go', 'happy', 'house', 'left', 'marvin', 'nine', 'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree', 'two', 'up', 'wow', 'yes', 'zero']

# %%
files = []
for class_name in all_classes:
    class_files = list((data_dir/class_name).glob("*.wav"))
    files += class_files

files = [str(f) for f in files]
print("Total audio files:", len(files))
# Out:
# Total audio files: 64721

# %%
class_names.remove('_background_noise_')

# %%
import numpy as np

def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(
        waveform,
        frame_length=255,
        frame_step=128
    )
    spectrogram = tf.abs(spectrogram)
    spectrogram = spectrogram[..., tf.newaxis]
    return spectrogram

# %%
def preprocess(audio, label):
    audio = tf.squeeze(audio, axis=-1)
    spectrogram = get_spectrogram(audio)
    return spectrogram, label

train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)
